# %% [markdown]
# # 1) Pairs , NLTK

# %% [markdown]
# ## a)

# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define pairs of patterns and responses
pairs = [
    ["hello|hi|hey", ["Hello!", "Hi there!", "Hey!"]],
    ["how are you|how's it going", ["I'm good, thanks!", "I'm doing well, how about you?"]],
    ["what's your name", ["I'm a chatbot.", "I'm just a bot."]],
    ["bye|goodbye", ["Goodbye!", "See you later!"]],
    ["", ["I'm not sure I understand.", "Could you please rephrase that?"]]
]

# Create a chatbot using the defined pairs
chatbot = Chat(pairs, reflections)

# Start the conversation
print("Hello! I'm a simple chatbot. Type 'exit' to end the conversation.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye!")
        break
    response = chatbot.respond(user_input)
    print("Chatbot:", response)
# Out:
# Hello! I'm a simple chatbot. Type 'exit' to end the conversation.
# You: hi
# Chatbot: Hi there!
# You: hi
# Chatbot: Hi there!
# You: hi
# Chatbot: Hey!
# You: bye
# Chatbot: See you later!
# You: what's your name
# Chatbot: I'm a chatbot.
# You: what's your name
# Chatbot: I'm just a bot.
# You: what s your name
# Chatbot: I'm not sure I understand.
# You: exit
# Chatbot: Goodbye!

# %% [markdown]
# ## b)

# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define pairs of patterns and responses
pairs = [
    ["مرحبًا|مرحبا|مرحباً", ["مرحبًا!", "مرحباً بك!", "أهلاً!"]],
    ["كيف حالك|كيفك|شلونك", ["أنا بخير، شكرًا!", "أنا بأتم الصحة والعافية، وأنت؟"]],
    ["ما اسمك|شو اسمك|شو اسمك؟", ["أنا روبوت دردشة.", "أنا مجرد برنامج دردشة."]],
    ["وداعًا|إلى اللقاء|مع السلامة", ["وداعًا!", "أراك لاحقًا!"]],
    [".*", ["لم أفهم ما قلت. هل يمكنك إعادة صياغته؟", "عذرًا، يبدو أنني لم أتمكن من فهم ذلك."]]
]


# Create a chatbot using the defined pairs
chatbot = Chat(pairs, reflections)

# Start the conversation
print("الروبوت: مرحبًا! أنا روبوت دردشة. اكتب 'وداعًا' لإنهاء المحادثة.")
while True:
    user_input = input("أنت: ")
    if user_input.lower() == 'خروج':
        print("الروبوت: وداعًا!")
        break
    response = chatbot.respond(user_input)
    print("الروبوت:", response)
# Out:
# الروبوت: مرحبًا! أنا روبوت دردشة. اكتب 'وداعًا' لإنهاء المحادثة.
# أنت: مرحبا
# الروبوت: مرحبًا!
# أنت: مرحبا
# الروبوت: مرحباً بك!
# أنت: شو اسمك؟
# الروبوت: أنا مجرد برنامج دردشة.
# أنت: شو اسمك؟
# الروبوت: أنا مجرد برنامج دردشة.
# أنت: شو اسمك
# الروبوت: أنا مجرد برنامج دردشة.
# أنت: شو   اسمك؟
# الروبوت: عذرًا، يبدو أنني لم أتمكن من فهم ذلك.
# أنت: خروج
# الروبوت: وداعًا!

# %% [markdown]
# # 2) Transformers

# %% [markdown]
# ## a)

# %% [markdown]
# https://github.com/microsoft/DialoGPT

# %%
# !pip install  transformers
import transformers
nlp = transformers.pipeline("conversational", model="microsoft/DialoGPT-medium")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.3 MB/s eta 0:00:00
# ...

# %%
while True :
  T = input()
  if T =='q' : break
  print(nlp(transformers.Conversation(T)))
# Out:
# hi
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Conversation id: 7cf77322-f798-4d4e-b3a8-4c45feb4caa4
# user >> hi
# bot >> Hey! :D
#
# how are you
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...

# %% [markdown]
# ## b)

# %%
# !pip install  transformers
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer


model = GPT2LMHeadModel.from_pretrained("gpt2")
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

torch.manual_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print("Smart Chatbot: Hello! I'm a smart chatbot. Type 'exit' to end the conversation.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Smart Chatbot: Goodbye!")
        break

    # Encode user input and generate response
    input_ids = tokenizer.encode(user_input, return_tensors="pt").to(device)
    with torch.no_grad():
        output = model.generate(input_ids, max_length=100, num_return_sequences=1)

    response = tokenizer.decode(output[0], skip_special_tokens=True)
    print("Smart Chatbot:", response)
# Out:
# ...
# Smart Chatbot: Hello! I'm a smart chatbot. Type 'exit' to end the conversation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Smart Chatbot: hi, who was born in the city of Kolkata, was a member of the Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolk
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Smart Chatbot: how are you going to do it?"
#
# ...

# %% [markdown]
# ## c)

# %%
# !pip install  transformers
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch


tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("microsoft/DialoGPT-medium")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 60.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.2 MB/s eta 0:00:00
# ...

# %%
Start = True
while True :
  T = input(">> User:")
  if T =='q' or T == 'exit': break
  new_user_input_ids = tokenizer.encode(T + tokenizer.eos_token, return_tensors='pt')
  bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if not Start  else new_user_input_ids
  Start = False
  chat_history_ids = model.generate(bot_input_ids, max_length=1000, pad_token_id=tokenizer.eos_token_id)
  print("DialoGPT: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# >> User:exit

# %% [markdown]
# ## d) Español

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("erikycd/chatbot_hadita")
model = AutoModelForCausalLM.from_pretrained("erikycd/chatbot_hadita")
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
model = model.to(device)

# %%
def infer(inp):
    inp = "<startofstring> "+ inp +" <bot>: "
    inp = tokenizer(inp, return_tensors = "pt")
    X = inp["input_ids"].to(device)
    attn = inp["attention_mask"].to(device)
    output = model.generate(X, attention_mask = attn, pad_token_id = tokenizer.eos_token_id)
    output = tokenizer.decode(output[0], skip_special_tokens = True)
    return output

exit_commands = ('bye', 'quit')
text = ''
while text not in exit_commands:

    text = input('\nUser: ')
    output = infer(text)
    print('Bot: ', output)
# Out:
# User: hi
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1254: UserWarning: Using the model-agnostic default `max_length` (=20) to control thegeneration length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Bot:   hi <bot>: es muy amable de tu parte
#
# User: what is ur name
# Bot:   what is ur name <bot>: es algo natural
#
# User: buenos dias
# Bot:   buenos dias <bot>: es un nuevo regalo   e
#
# User: como te llamas ?
# Bot:   como te llamas?  <bot>: es un buen tipo de hombre
#
# User: donde esta egipto ?
# Bot:   donde esta egipto?  <bot>: es el porque
#
# User: bye
# Bot:   bye <bot>: es un regalo

# %% [markdown]
# ## e) Movies

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("bluenguyen/movie_chatbot_v1")
model = AutoModelForSeq2SeqLM.from_pretrained("bluenguyen/movie_chatbot_v1").to('cpu')

# %%
def current_context(dialog, instruction):
    dialog = ' EOS '.join(dialog)
    context = f"{instruction} [CONTEXT] {dialog} "
    return context

def generate(context):
    input_ids = tokenizer(f"{context}", return_tensors="pt").input_ids.to('cpu')
    outputs = model.generate(input_ids, max_length=128, min_length=8, top_p=0.9, do_sample=True)
    output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return output

instruction = f'Instruction: given a dialog about movie recommendation, you need to respond based on human preferences.'
dialog = [
    'Do you have any recommendation about a movie?',
    'Yes! Any particular genre that you\'d like to see mentioned?',
]
print('User: ' + dialog[0])
print('Bot: ' + dialog[1])
while(1):
    print('User: ', end = '')
    query = input()
    if query == 'end':
        break
    dialog.append(query)
    response = generate(current_context(dialog, instruction))
    print('Bot: ' + response)
    dialog.append(response)
# Out:
# User: Do you have any recommendation about a movie?
# Bot: Yes! Any particular genre that you'd like to see mentioned?
# User: Do you have any recommendation about a movie
# Bot: Sure, what type of movie are you interested in?
# User: kindly tell me a film to be romantic not horror
# Bot: Have you seen "Crazy, Stupid, Love"? It's a romantic horror movie about a middle-aged man who goes through a divorce and starts adjusting to the romance world.
# User: kindly tell me a film to be horror not romantic
# Bot: How about "Hereditary"? It's a psychological horror film about a family that seeks the help of a family's cryptic secrets unreasonable to find love.
# User: what about godfather
# Bot: Have you seen "The Godfather"? It's a classic movie about the Corleone family and their struggle to survive in the mafia.
# User: tell me  a classic musical film
# ...

# %% [markdown]
# ## f)

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead
tokenizer = AutoTokenizer.from_pretrained("r3dhummingbird/DialoGPT-medium-joshua")
model = AutoModelWithLMHead.from_pretrained("r3dhummingbird/DialoGPT-medium-joshua")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1468: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# ...

# %%
for step in range(100):
    Input = input(">> User:")
    if Input =='quit' : break
    new_user_input_ids = tokenizer.encode(Input + tokenizer.eos_token, return_tensors='pt')
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids
    chat_history_ids = model.generate(
        bot_input_ids, max_length=200,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3,
        do_sample=True,
        top_k=100,
        top_p=0.7,
        temperature=0.8
    )

    print("JoshuaBot: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# >> User:hi
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# JoshuaBot: Hey there.
# >> User:how r u
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# JoshuaBot: I'm fine. You?
# >> User:what is ur name
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# JoshuaBot: I don't really know... It's something I picked up on while I was at UG.
# >> User:how is ur health ?
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...

# %% [markdown]
# ## g)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("Ahmade/doctor_chatbot_v2")
model = AutoModelForCausalLM.from_pretrained("Ahmade/doctor_chatbot_v2")

# %%
def chat(model, tokenizer):
  print("type q to quit. Automatically quits after 5 messages")

for step in range(5):
    message = input("MESSAGE: ")

    if message in ["", "q"]:
        break

    new_user_input_ids = tokenizer.encode(message + tokenizer.eos_token, return_tensors='pt')
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids
    chat_history_ids = model.generate(
        bot_input_ids,
        max_length=1000,
        pad_token_id=tokenizer.eos_token_id,
        no_repeat_ngram_size=3,
        do_sample=True,
        top_k=100,
        top_p=0.7,
        temperature = 0.8,
    )

    print("DialoGPT: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# MESSAGE: hi
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# DialoGPT: hi    welcome to healthcaremagic forum  i have gone through your question and understand your concerns  i would like to tell you that the condition you are describing is called post infectious bronchitis   it is due to the infection of the lungs   this is caused by the bacterial flora in the airways   the bacteria in the lungs will not respond to the treatment  however  i will suggest you to consult a pulmonologist for the
# MESSAGE: I have a headache
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# DialoGPT: !!!
# MESSAGE: tell me more about HIV
# ...

# %% [markdown]
# ## h)

# %%
from transformers import EncoderDecoderModel, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("tareknaous/bert2bert-empathetic-response-msa")
model = EncoderDecoderModel.from_pretrained("tareknaous/bert2bert-empathetic-response-msa")
model.to("cpu")
model.eval()
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:399: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# EncoderDecoderModel(
#   (encoder): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
# ...

# %%
# !pip install pyarabic
# !pip install farasapy
# !git clone https://github.com/aub-mind/arabert

from arabert.preprocess import ArabertPreprocessor
arabert_prep = ArabertPreprocessor(model_name="bert-base-arabert", keep_emojis=False)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 3.9 MB/s eta 0:00:00
# ...
# Cloning into 'arabert'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 600 (delta 38), reused 45 (delta 30), pack-reused 535
# Receiving objects: 100% (600/600), 9.14 MiB | 24.70 MiB/s, done.
# Resolving deltas: 100% (339/339), done.
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'farasa-api.qcri.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 100%|██████████| 241M/241M [00:21<00:00, 11.4MiB/s]
# [2023-08-27 10:49:53,267 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
def generate_response(text):
  text_clean = arabert_prep.preprocess(text)
  inputs = tokenizer.encode_plus(text_clean,return_tensors='pt')
  outputs = model.generate(input_ids = inputs.input_ids.to("cpu"),
                   attention_mask = inputs.attention_mask.to("cpu"),
                   do_sample = True,
                   min_length=10,
                   top_k = 0,
                   top_p = 0.9,
                   temperature = 0.5)
  preds = tokenizer.batch_decode(outputs)
  response = str(preds)
  response = response.replace("\'", '')
  response = response.replace("[[CLS]", '')
  response = response.replace("[SEP]]", '')
  response = str(arabert_prep.desegment(response))
  return response

# %%
ExitWords =['باي','خروج','انهاء','إنهاء','مع السلامة','مع السلامه' ,'إنتهاء'   ]

print('الرد الآلي : أهلا بكم في الرد الآلي الذكي, ما هو سؤالك ؟ ؟ ')

while True :
  Question = input('')

  if Question.lower() in ExitWords :
    print('الرد الآلي : شكرا لكم و نراكم قريبا')
    break
  print(f'الرد الآلي : {generate_response(Question)}')


print('-------------------------------------------------')
# Out:
# الرد الآلي : أهلا بكم في الرد الآلي الذكي, ما هو سؤالك ؟ ؟
# اهلا بيك
# الرد الآلي :  يا رجل. هل لديك أي خطط لعيد الميلاد ؟
# اسمك ايه
# الرد الآلي :  أوه ، واو!كم من الوقت استغرقت للحصول على واحدة ؟
# ما هي عاصمة الكويت
# الرد الآلي :  أنا أحب السفر. هل ستذهب إلى هناك ؟
# خروج
# الرد الآلي : شكرا لكم و نراكم قريبا
# -------------------------------------------------

# %% [markdown]
# ## I)

# %%
# !pip install transformers
# !pip install torch
# !pip install -U deep_translator
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 770.9 kB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
from warnings import filterwarnings
filterwarnings('ignore')
from transformers import AutoModelForCausalLM, AutoTokenizer,AutoModelWithLMHead
import torch

tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("microsoft/DialoGPT-medium")

# %%
def Chat(Text) :
    Text = GoogleTranslator(source='ar', target='en').translate(Text)
    print(Text)
    Start = True
    Input = Text
    new_user_input_ids = tokenizer.encode(Input + tokenizer.eos_token, return_tensors='pt')
    bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if not Start else new_user_input_ids
    Start = False
    chat_history_ids = model.generate(bot_input_ids, max_length=1000, pad_token_id=tokenizer.eos_token_id)
    ThisReply = tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)
    Text = GoogleTranslator(source='en', target='ar').translate(ThisReply)
    return Text

while True :
  T =  input('Bot:')
  if T =='q' : break
  print(Chat(T))
# Out:
# Bot:اسمك ايه
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# What is your name
# لست متأكدًا، لكن أعتقد أنها إشارة إلى فيلم The Big Lebowski.
# Bot:q

# %% [markdown]
# ## J)

# %% [markdown]
# https://platform.openai.com/account/api-keys.

# %%
# !pip install openai

import openai,os,time
# import pandas as pd
openai.api_key = '**********************************************'
def get_completion(prompt, model="gpt-3.5-turbo"):
  messages = [{"role": "user", "content": prompt}]
  response = openai.ChatCompletion.create(model=model,messages=messages,temperature=0,)
  return response.choices[0].message["content"]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# As an AI language model, I do not have a name. You can call me OpenAI's language model or simply AI.

# %%
while True :
  T = input('GPT:')
  if T =='q' : break
  print(get_completion(T))
# Out:
# GPT:hi
# Hello! How can I assist you today?
# GPT:what is population of france
# As an AI language model, I do not have access to real-time data. However, according to the World Bank, the estimated population of France in 2021 is approximately 67 million people.
# GPT:تتكلم عربي ؟
# نعم، أنا برنامج حاسوبي قادر على التحدث باللغة العربية.
# GPT:قول قصة باللغة العربية
# كان هناك مرة واحدة في قديم الزمان، في قرية صغيرة، كان هناك شاب يدعى علي. كان علي شابًا طموحًا ومجتهدًا، وكان يحلم بأن يصبح رجلًا غنيًا وناجحًا.
#
# في يوم من الأيام، قرر علي الذهاب إلى المدينة الكبيرة للعمل وتحقيق أحلامه. وبعد أشهر من العمل الشاق، تمكن علي من تحقيق أحلامه وأصبح رجلًا غنيًا وناجحًا.
#
# لكن عندما عاد إلى قريته، وجد أن القرية قد تغيرت تمامًا. كانت القرية الهادئة والجميلة قد تحولت إلى مكان مليء بالفساد والظلم. وكان الناس يعانون من الفقر والجوع والظلم.
#
# فقرر علي أن يستخدم ثروته ونجاحه لمساعدة الناس في قريته. بدأ علي ببناء مدارس ومستشفيات ومساعدة الناس في الحصول على العمل والغذاء.
#
# ...
